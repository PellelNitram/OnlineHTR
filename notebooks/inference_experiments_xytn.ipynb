# %% [markdown]
# # Inference experiments `xytn`

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from torchmetrics.functional.text import word_error_rate
from torchmetrics.functional.text import char_error_rate
import matplotlib.pyplot as plt
from torchvision.transforms import transforms
from torch.utils.data import DataLoader

from src.models.carbune_module import CarbuneLitModule2
from src.models.carbune_module import LitModule1
from src.models.components.carbune2020_net import Carbune2020NetAttempt1
from src.utils.io import load_alphabet
from src.data.tokenisers import AlphabetMapper
from src.data.online_handwriting_datamodule import IAMOnDBDataModule
from src.data.online_handwriting_datasets import XournalPagewiseDataset
from src.data.online_handwriting_datasets import IAM_OnDB_Dataset
from src.data.online_handwriting_datasets import Own_Dataset
from src.data.online_handwriting_datasets import get_alphabet_from_dataset
from src.data.transforms import SimpleNormalise
from src.data.transforms import DictToTensor
from src.data.transforms import CharactersToIndices
from src.data.transforms import Carbune2020
from src.data.collate_functions import my_collator

# %%
BASE_PATH = Path('../logs/train/multiruns/2024-04-10_20-09-25/8')
CHECKPOINT_PATH = BASE_PATH / 'checkpoints/epoch000749.ckpt'

model = LitModule1.load_from_checkpoint(CHECKPOINT_PATH)

model.eval()
# Out:
# /localdisk/s1691089/venvs/carbune2020/lib/python3.10/site-packages/lightning/pytorch/utilities/migration/utils.py:55: The loaded checkpoint was produced with Lightning v2.2.1, which is newer than your current Lightning version: v2.1.3
# /localdisk/s1691089/venvs/carbune2020/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:198: Attribute 'decoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['decoder'])`.
# LitModule1(
#   (criterion): CTCLoss()
#   (log_softmax): LogSoftmax(dim=2)
#   (lstm_stack): LSTM(4, 64, num_layers=3, dropout=0.25, bidirectional=True)
#   (linear): Linear(in_features=128, out_features=82, bias=True)
# )

# %%
checkpoint = torch.load(CHECKPOINT_PATH, map_location=lambda storage, loc: storage)
list(checkpoint.keys())
# Out:
# ['epoch',
#  'global_step',
#  'pytorch-lightning_version',
#  'state_dict',
#  'loops',
#  'callbacks',
#  'optimizer_states',
#  'lr_schedulers',
#  'hparams_name',
#  'hyper_parameters',
#  'datamodule_hparams_name',
#  'datamodule_hyper_parameters']

# %%
alphabet = load_alphabet(BASE_PATH / 'alphabet.json')
alphabet_mapper = AlphabetMapper( alphabet )
decoder = checkpoint['hyper_parameters']['decoder']

# %% [markdown]
# ### Load data: From IAMOnDB

# %%
dm = IAMOnDBDataModule(**checkpoint['datamodule_hyper_parameters']) # This ensures correct DataModule as it's
                                                                    # consistent w/ checkpoint
dm.setup()
dl_val = dm.val_dataloader()
dl_train = dm.train_dataloader()
# Out:
# /localdisk/s1691089/venvs/carbune2020/lib/python3.10/site-packages/torch/utils/data/dataset.py:414: UserWarning: Length of split at index 2 is 0. This might result in an empty dataset.
#   warnings.warn(f"Length of split at index {i} is 0. "

# %% [markdown]
# ### Do inference on train and val datasets: IAMOnDB

# %%
df_data = {
    'name': [],
    'type': [],
    'value': [],
}

for name, dloader in { 'train': dl_train, 'val': dl_val }.items():
    for sample_batched in dloader:
        batch = sample_batched # Just a shortcut

        with torch.no_grad():
            log_softmax = model(sample_batched['ink'].to('cuda'))

        decoded_texts = decoder(log_softmax, alphabet_mapper)

        labels = batch['label_str']

        cer = char_error_rate(preds=decoded_texts, target=labels)
        wer = word_error_rate(preds=decoded_texts, target=labels)

        df_data['name'].append(name)
        df_data['type'].append('cer')
        df_data['value'].append(cer.item())

        df_data['name'].append(name)
        df_data['type'].append('wer')
        df_data['value'].append(wer.item())

df = pd.DataFrame.from_dict(df_data)

# %%
df.groupby(['name', 'type']).mean()
# Out:
#                value
# name  type
# train cer   0.026607
#       wer   0.134847
# val   cer   0.062018
#       wer   0.252502

# %% [markdown]
# Reloading seems to work as this performance is roughly what I can observe in TenorBoard!
#
# Strangely, the `train` values change (both cer and wer) when re-executing but not the `val` values. Question: also when re-executing the cell? Re question: I have checked manually that the reason is `shuffle=True` in train `DataLoader`. However, I don't know why the order of the same samples should influence a metric that takes in all samples. Strange! But probably not relevant for now.

# %% [markdown]
# ### Load data: From XournalPagewise

# %% [markdown]
# This requires a custom built transform for the Dataset b/c one needs to use training alphabet!

# %%
# GET STANDALONE DATASET

# This is the one that I really want to use
dataset = Own_Dataset(
    Path('../data/datasets/own_test_dataset'),
    transform=None,
)

# This is the one to validate my code; result: yes it works! Just uncomment this to test it
dataset = IAM_OnDB_Dataset(Path('../data/datasets/IAM-OnDB'),
                           transform=None,
                           limit=-1,
                           skip_carbune2020_fails=True)

print(f'Number of samples in dataset: {len(dataset)}')

alphabet_inference = get_alphabet_from_dataset( dataset )
for letter in alphabet_inference: # Confirm that there are no OOV letters
    assert letter in alphabet

transform = transforms.Compose([
    Carbune2020(),
    DictToTensor(['x', 'y', 't', 'n']),
    CharactersToIndices( alphabet ), # TODO: Why does it only work if CTI is last?
])

dataset.transform = transform

# # GET STANDALONE DATALOADER

dl_inference = DataLoader(
    dataset=dataset,
    batch_size=64,
    num_workers=4,
    pin_memory=True,
    shuffle=False,
    collate_fn=my_collator,
)
# Out:
# Number of samples in dataset: 12120

# %% [markdown]
# ### Do inference: XournalPagewise

# %%
df_data = {
    'name': [],
    'type': [],
    'value': [],
}

# for name, dloader in { 'train': dl_train_xp, 'val': dl_val_xp }.items():
for name, dloader in { 'inference': dl_inference, }.items():
    for sample_batched in dloader:
        batch = sample_batched # Just a shortcut

        with torch.no_grad():
            log_softmax = model(sample_batched['ink'].to('cuda'))

        decoded_texts = decoder(log_softmax, alphabet_mapper)

        labels = batch['label_str']

        for pred, truth in zip(decoded_texts, labels):
            print(f'"{pred}" <> "{truth}"')

        cer = char_error_rate(preds=decoded_texts, target=labels)
        wer = word_error_rate(preds=decoded_texts, target=labels)

        df_data['name'].append(name)
        df_data['type'].append('cer')
        df_data['value'].append(cer.item())

        df_data['name'].append(name)
        df_data['type'].append('wer')
        df_data['value'].append(wer.item())

df = pd.DataFrame.from_dict(df_data)
# Out:
# "It was a qurer piace and l" <> "It was a quiet place and I"
# "was glad. Ineeded to be able" <> "was glad. I needed to be able"
# "in Soho, to get me used to" <> "in Soho, to get me used to"
# "He chose a Greek resraurant" <> "He chose a Greek restaurant"
# ""Tell me about it white" <> ""Tell me about it while"
# "the food, he said." <> "the food, he said."
# "we eat."" <> "we eat.""
# "to talk." <> "to talk."
# "better pluces, "he commented. "" <> "better places, " he commented.""
# "bridge. " " I know it. "" <> "bridge. " " I know it. ""
# "There 's a place just below" <> "There 's a place just below"
# "I know, but that's where I 'm" <> "I know, but that 's where I 'm"
# "going." <> "going."
# "Bretcham, near the foot-" <> "Bletcham, near the foot-"
# "He looked doubtful. "There are" <> "He looked doubtful. "There are"
# ""No," he said at last. "I can'" <> ""No," he said at last. "I can't"
# "married now I could come" <> "married now I could come"
# "stop me." "I can do better than" <> "stop me." "I can do better than"
# "allon it." "You cun't very rell" <> "allow it." "You can't very well"
# "that. If we wer to get" <> "that. If we were to get"
# "with you."" <> "with you.""
# "I could not endure the thought of" <> "I could not endure the thought of"
# "river road." <> "river road."
# "was there punctually. He settled me" <> "was there punctually. He settled me"
# "into the car with touching care and" <> "into the car with touching care and"
# "another wait at the bus station. He" <> "another wait at the bus station. He"
# ""No," I said 'outside your Office. "" <> ""No," I said, "outside your Office.""
# "then drove like a friend along the" <> "then drove like a friend along the"
# "by his manner, which was most" <> "by his manner, which was most"
# "was, perhaps, a shad too friendly." <> "was, perhaps, a shade too friendly."
# "attraktive in its friendliness. This" <> "attractive in its friendliness. This"
# "I was touched and flattered" <> "I was touched and flattered"
# "young man was ignoring the" <> "young man was ignoring the"
# "did not ockure to me util" <> "did not occur to me until"
# "a long time afterwards that he" <> "a long time afterwards that he"
# "defences and I tike him for it. It" <> "defences and I liked him for it. It"
# "wvengthig I caw about him. "" <> "everything I can about him. ""
# "house, "I rushed on."" <> "house, "I rushed on.""
# "" Why?"" <> "" Why? ""
# "and moor it near Hardy's" <> "and moor it near Hardy's"
# "I 'm going to find out" <> "I 'm going to find out"
# "I 'o going to buy a boat" <> "I 'm going to buy a boat"
# "I was afraid if he came near it" <> "I was afraid, if he came near it"
# "again, that I should never see the last of" <> "again, that I should never see the last of"
# ""No, thank you, Clive. I shall be" <> ""No, thank you, Clive. I shall be"
# "drove me back to Bletcham and we" <> "drove me back to Bletcham and we"
# "him." <> "him."
# "parted like old friends. He suggested" <> "parted like old friends. He suggested"
# "ano ther meeting, bot I refused; the" <> "another meeting, but I refused; the"
# "boat was such an attraction that" <> "boat was such an attraction that"
# "able to manage. Afterwands he" <> "able to manage. Afterwards he"
# "before #2 gotused to calling" <> "before # I got used to calling"
# ""That's her, " he said." <> "" That ' s her, " he said."
# "catching craft. It was a long time" <> "catching craft. It was a long time"
# "in." <> "in."
# "pronourced me aicerworthy and" <> "pronounced me riverworthy and"
# "them portholes. At last he" <> "them portholes. At last he"
# "wanted to know whenlI would be" <> "wanted to know when I would be moving"
# ""Sand piper." 'he was not an ene-" <> "" Sandpiper. " ' he was not an eye-"
# "to keep myself going betwreen" <> "to keep myself going between"
# "when I was a kid. And then I acted" <> "when I was a kid. And then I acted"
# "as guide on a river boat one summer," <> "as guide on a river boat one summer,"
# ""I used to play aboue in these things" <> ""I used to play about in these things"
# "term, at college." <> "terms at college."
# ""I wasn't going to, " I said. "I shin't be" <> "" I wasn ' t going to, " I said. " I shan ' t be"
# ""Cold water sirts you. Don't complain. "" <> "" Cold water suits you. Don ' t complain. ""
# "herc much longer. " "I unow. Yon're coming" <> "here much longer. " " I know. You ' re coming"
# "to Greece with me. "" <> "to Greece with me. ""
# "tat tine I 'll give up" <> "that time I ' ll give up"
# "I can't wait forever, i you know." <> "I can ' t wait for ever, you know."
# "I baven't discovered anything by" <> "I haven ' t discovered anything by"
# "time, Max, say three months. I" <> "time, Max, say three months. If"
# ""I know. Just give me a little" <> "" I know. Just give me a little"
# "trying."" <> "trying. ""
# "auspiaion remained in my head" <> "suspicion remained in my head"
# "mornents of optimism, that it was" <> "moments of optimism, that it was"
# "s could pretend to myself, in" <> "I could pretend to myself, in"
# "I sain lamely." <> "I said lamely."
# "As long as my suspect" <> "As long as my suspect"
# "not true. "It could hare been anyone,"" <> "not true. "It could have been anyone,""
# "his wiry frame through the cabiin" <> "his wiry frame through the cabin"
# "Like Clive, he was enthusiastc" <> "Like Clive, he was enthusiastic"
# "doorand wtndered abant inside," <> "door and wandered about inside,"
# "We climred aboard and he eased" <> "We climbed aboard and he eased"
# "opening everthing that would open." <> "opening everything that would open."
# "an me rfrength of its efficiency, thoat" <> "on the strength of its efficiency, that"
# "about the engine and decided, apparently" <> "about the engine and decided, apparently"
# "Sandpuper wars fit to live in." <> "Sandpiper was fit to live in."
# "I'll run you up there in the car. "" <> "I 'll run you up there in the car.""
# ""ou can see it any time you like,"" <> ""You can see it any time you like,""
# "you can set to Bletcham this evening" <> "you can get to Bletcham this evening"
# "he told me. "The sooner the better. If" <> "he told me. "The sooner the better. If"
# "aren't you?"." <> "aren ' t you? ""
# "'re already certain that he did it," <> "' re already certain that he did it,"
# "went on: " There won't be any happiness" <> "went on: " There won ' t be any happiness"
# "for me until I can prove him guitty." "You" <> "for me until I can prove him guilty. " " You"
# "When the pouring ritual was over he" <> "When the pouring ritual was over he"
# "at the end of a vebvety lazun flanked" <> "at the end of a velvety lawn flanked"
# "side, Rivermead was less forbidding, it" <> "side, Rivermead was less forbidding; it"
# ""That makes two of us. " Fram this" <> ""That makes two of us." From this"
# "stood a lang way back from the water" <> "stood a long way back from the water"
# "wiith flowering trees and shrubs." <> "with flowering trees and shrubs."
# "and given hes proper place in the hiitory of" <> "and given his proper place in the history of"
# "tougve - in-cheek "whherliche Geschechten"" <> "tongue-in-cheek "Unheimliche Geschichten""
# "(1920), five ghost stories with a lighr touch" <> "(1920) , five ghost stories with a light touch"
# "and there was much to admine" <> "and there was much to admire"
# "Thus cirector is at last being re- evaluated" <> "This director is at last being re-evaluated"
# "the German film. Most charming was his" <> "the German film . Most charming was his"
# "France and shoun last" <> "France and shown last"
# "criously translated into Seven" <> "curiously translated into Seven"
# "Belmondo reappears at" <> "Belmondo reappears at"
# "Moderato Cantabile (" <> "Moderato Cantabile ("
# "atumn at" <> "autumn at"
# "Duys ... Seven fighls ... A contificate)," <> "Days . . . Seven Nights  . . . A certificate) ,"
# "the same, now even clearer, but" <> "the same, now even clearer, but"
# "camera has never been more exciting," <> "camera has never been more exciting,"
# "touched with a melancholy compassion" <> "touched with a melancholy compassion"
# "maturity of his ultimate artistic vision." <> "maturity of his ultimate artistic vision."
# "skyscrapers of Milan. But his society is" <> "skyscrapers of Milan. But his society is"
# "exchanging the rocks of Sicily for the" <> "exchanging the rocks of Sicily for the"
# "His method of painting with the" <> "His method of painting with the"
# "which is a strong sign of the" <> "which is a strong sign of the"
# "is given a gala seciety reopening on the" <> "is given a gala society reopening on the"
# "the Antonioni and Wicki films" <> "the Antonioni and Wicki films"
# "unusuully generous in giving everyone" <> "unusually generous in giving everyone"
# "a crouning indignity the night club" <> "a crowning indignity the night club"
# "island. Tather malachias goes to the" <> "island. Father Malachias goes to the"
# "Prizes being twhat they are, Berlin is" <> "Prizes being what they are , Berlin is"
# "oniginal sething," <> "original setting."
# "something, and silver bears are" <> "something , and silver bears are"
# "monk for his miracle, and as" <> "monk for his miracle, and as"
# "took high honoun," <> "took high honours ,"
# "island, prays, and in a seced miradle" <> "island, prays, and in a second miracle"
# "Sentonce Database C02-0s9" <> "Sentence Database  C02-059"
# "awarded in every direction. Both" <> "awarded in every direction . Both"
# "The Church rebukes the poer" <> "The Church rebukes the poor"
# "the night club is repecd in its" <> "the night club is replaced in its"
# "an actor, had his first" <> "an actor, had his first"
# "in Africa and America." <> "in Africa and America."
# "and he also appears in" <> "and he also appears in"
# "195'0 he began to take photograp" <> "1950 he began to take photograph"
# "important film role in" <> "important film role in"
# "not only in Germany but also" <> "not only in Germany but also"
# "He began his career as" <> "He began his career as"
# "the new Antonimni film. In" <> "the new Antonioni film. In"
# "Ko utner's p die letat brEcke"" <> "Kautner's "die letzt brucke,""
# "suddenly jolted back to life by two" <> "suddenly jolted back to life by two"
# "fatal ennui, the eleventh Berlin" <> "fatal ennui , the eleventh Berlin"
# "AFTER ten dlays of intermittent, near" <> "AFTER ten days of intermittent , near"
# "Inteinational Film Festival was" <> "International Film Festival was"
# "extroordinary flms, Bernhard licki's" <> "extraordinary films , Bernhard Wicki ' s"
# ""Das Hunder des Malachias" I" The" <> ""Das Wunder des Malachias" ("The"
# "as of of- the-cff living," <> "as of off-the-cuff living ,"
# "that once seemed so new" <> "that once seemed so new"
# "abore all of cinematic" <> "above all of cinematic"
# "and so" <> "and so"
# "that air of imprevisation ," <> "that air of improvisation ,"
# "about it , of encormous" <> "about it , of enormous"
# "It has a great look of" <> "It has a great look of"
# "speed and. technical fun" <> "speed and technical fun"
# "sense. Much of it has" <> "sense . Much of it has"
# "cinematic enjoyment, arnd" <> "cinematic enjoyment , and"
# "last days of the Third Reich with" <> "last days of the Third Reich with"
# "more intimate and deeply felt. In" <> "more intimate and deeply felt . In"
# "the sinking of the great ocean liner," <> "the sinking of the great ocean liner ,"
# "1944 Herbert Selpin tried a similar" <> "1944 Herbert Selpin tried a similar"
# "a cut-rate "Dolce Vita" for itis far" <> "a cut-rate "Dolce Vita ," for it is far"
# "feat in "Ttavic" by paralleling the" <> "feat in "Titanic" by paralleling the"
# "It is most unfair to call "Malachias"" <> "It is most unfair to call "Malachias""
# "Wicki the photographer as to Wicki" <> "Wicki the photographer as to Wicki"
# "accuracy of a police photograph;" <> "accuracy of a police photograph,"
# "eternal in every instant. "The chilling" <> "eternal in every instant. "The chilling"
# "He does not want the" <> "He does not want the"
# "horror of"Malachins"is due as much to" <> "horror of" Malachias "is due as much to"
# "but rather he wants to show the" <> "but rather he wants to show the"
# "the director." <> "the director."
# "extreme coolness, much preferring" <> "extreme coolness , much preferring"
# "hinety-one minute hyme to" <> "ninety-one minute hymn to"
# "Strangely enough, the Berlin" <> "Strangely enough , the Berlin"
# "Jean.Luc Godard's disappointing" <> "Jean-Luc Godard ' s disappointing"
# ""Une Femme est une Femme," a" <> ""Une Femme est une Femme ," a"
# "andience received the film with" <> "audience received the film with"
# ""Vogue' "Cahiers dn Cinema" and the" <> ""Vogue ," "Cahiers du Cinema ," and the"
# "but also in Africa and America. An" <> "but also in Africa and America . An"
# "photographs not only in Germany" <> "photographs not only in Germany"
# "exhibition of hese works which is now" <> "exhibition of these works which is now"
# "impressive. As friedrich Dirremmatt ," <> "impressive . As Friedrich Du"rrenmatt ,"
# "In 1950 he began to take" <> "In 1950 he began to take"
# "the Swiss" <> "the Swiss"
# "on vew in a Berlin gallery is most" <> "on view in a Berlin gallery is most"
# "Wicki Suddenly returns to the" <> "Wicki Suddenly returns to the"
# "city for a final epilogue. Wicki has" <> "city for a final epilogue. Wicki has"
# "his personal apocalypse of the last days of" <> "his personal apocalypse of the last days of"
# "succeeded in his second film in recording" <> "succeeded in his second film in recording"
# "a sick society." <> "a sick society."
# "he said, "when we may be" <> "he said, "when we may be"
# "discuss this matter later,"" <> "discuss this matter later,""
# "really pay great attention,"" <> "really pay great attention,""
# "Julia felt a trifle" <> "Julia felt a trifle"
# "he cut her short. "We will" <> "he cut her short. "We will"
# "she began, but imperiously" <> "she began, but imperiously"
# "uncomfortable. "I didn't" <> "uncomfortable. "I didn't"
# "private." <> "private."
# "He could not be blamed for" <> "He could not be blamed for"
# "behaving in that high-handed" <> "behaving in that high-handed"
# "his voice and manner." <> "his voice and manner."
# "this father's State mind. He" <> "this father's State of mind. He"
# "fashios. She felt herself stiff-" <> "fashios. She felt herself stiff"
# "ehing again os she remembered" <> "ening again as she remembered"
# "has no right to dictate to her," <> "had no right to dictate to her,"
# "have heard about me, Miss Barclay." <> "have heard about me, Miss Barclay.""
# "hesitated." <> "hesitated."
# "Then he lifted his head and ashed" <> "Then he lifted his head and asked"
# "Well. I 'don't quite hnow-"Julio" <> "Well, I don't quite know - "Julia"
# "quictly: "I wonder what lales yon" <> "quietly: "I wonder what tales you"
# "tears brimming over and coursing" <> "tears brimming over and coursing"
# "Pepita stood there staring at fulia" <> "Pepita stood there staring at Julia"
# "eyes tilled with anguash, the" <> "eyes filled with anguish, the"
# "town her cheeks." <> "down her cheeks."
# "with all the happiness draining out" <> "with all the happiness draining out"
# "of her pretty little face. Her black" <> "of her pretty little face. Her black"
# "am round the sidls uck," <> "arms round the girl's neck,"
# "said." <> "said."
# "Julia lifted her up, and she" <> "Julia lifted her up, and she"
# "innidictely wonnd her small" <> "immediately wound her small"
# "wozzling he cheeck, snggling gant" <> "nuzzling her cheek, snuggling against"
# "watihed then. "fep ' estared,"he" <> "watched them. "Pep" restored," he"
# "her hair. Don Felixe smted as he" <> "her hair. Don Felipe smiled as he"
# "I Only wisl I could. "" <> "I Only wish I could. ""
# "con I stay? "Julin begon."" <> "can I stay? "Julia began.""
# "you obvrously ave. "" But howr" <> "you obviously are. "" But how"
# "who is a congeninn to ber as" <> "who is a congenial to her as"
# "It is rarely she finds a companion" <> "It is rarely she finds a companion"
# "trere was something quite off-beat" <> "there was something quite off-beat"
# "acknowledging the girl's greeting," <> "acknowledging the girl's greeting,"
# "ilence. Julia had already realised" <> "silence. Julia had already realised"
# "careful to address only Don Felipe" <> "careful to address only Don Felipe"
# "She bowed gruvely to Julia," <> "She bowed gravely to Julia,"
# "at her side throughout the meal." <> "at her side throughout the meal."
# "about Dona Beatriz, so she was" <> "about Dona Beatriz, so she was"
# "and began to serve in her usual" <> "and began to serve in her usual"
# "sighed, thinking how unkind fate could be" <> "sighed, thinking how unkind fate could be"
# "Julia felt depressed and a trifle" <> "Julia felt depressed and a trifle"
# "Felipe 's house on Saturday morning. She" <> "Felipe's house on Saturday morning. She"
# "at times. The morning began just the" <> "at times. The morning began just the"
# "sad as Luis conveyed her to Don" <> "sad as Luis conveyed her to Don"
# "same as the others." <> "same as the others."
# "Naturally it was a tremendous" <> "Naturally it was a tremendous"
# "we can do seems to be to" <> "we can do seems to be to"
# "concentrate on work, doesn't it?" <> "concentrate on work, doesn't it?"
# "carry on ourname. "The best thing" <> "carry on our name. "The best thing"
# "grief. We had hoped for sons to" <> "grief. We had hoped for sons to"
# ""This is awful," Julis exclaimed in" <> ""This is awful," Julia exclaimed in"
# "Pepits does not wish yau to lezve her,"" <> "Pepita does not wish you to leave her,""
# "consternation." <> "consternation."
# "desolate, as indeed lam mycelf."" <> "desolate, as indeed I am myself.""
# "Don Felipe said quietly. "She is" <> "Don Felipe said quietly. "She is"
# "he here at the same time then." <> "be here at the same time then."
# "generans in the extreme. "So gau will" <> "generous in the extreme. "So you will"
# ""On Monday we begin our new" <> ""On Monday we begin our new"
# "He naned a figure which Julia knew was" <> "He named a figure which Julia knew was"
# "arrargement, of couser I had thaught...."" <> "arrangement, of course. I had thought ....""
# "friendly beach and cafe life." <> "friendly beach and cafe life."
# "naturally I would pay you an" <> "naturally I would pay you an"
# "It would not be arduous, and" <> "It would not be arduous, and"
# "might continne to live at the Hotel" <> "might continue to live at the Hotel"
# "Tafira for the next few months," <> "Tafira for the next few months,"
# "enjoying the climate and the" <> "enjoying the climate and the"
# "ample salary. Julia nesitated. She" <> "ample salary. Julia hesitated. She"
# "the delicate operation before" <> "the delicate operation before"
# "himself a peach. He completed" <> "himself a peach. He completed"
# "his silver knife and looked" <> "his silver knife and looked"
# "at Julia directly ashespoke." <> "at Julia directly as he spoke."
# "Don Felipe had begun to peel" <> "Don Felipe had begun to peel"
# "he answered. Then he laid down" <> "he answered. Then he laid down"
# ""Thats right, alas. And you" <> ""Thats right, alas. And you"
# "won't want me here tomorrow, as" <> "won't want me here tomorrow, as"
# ""Ah, yes. You propose to sail" <> ""Ah, yes. You propose to sail"
# "it 's Sunday, of course."" <> "it 's Sunday, of course.""
# "home in the Juno, do you not?"" <> "home in the Juno, do you not?""
# "not penetrated the intenei of the itand" <> "not penetrated the interior of the island"
# "yet? No? It will surprise you." <> "yet? No? It will surprise you."
# "viiwed for the first time."" <> "viewed for the first time.""
# "The mouutains are so majestic they" <> "The mountains are so majestic they"
# "take the breoth away when they are" <> "take the breath away when they are"
# ""Yes, I should like to." " You have" <> ""Yes, I should like to." "You have"
# "thank you .... I cant bear to" <> "thank you .... I can't bear to"
# ""So you will stay, Miss" <> ""So you will stay, Miss"
# "Barclay?" "Yes, I will. And" <> "Barclay?" "Yes, I will. And"
# "the child's expresion change" <> "the child's expression change"
# "as her father spoke to her." <> "as her father spoke to her."
# "see her like this. She watched" <> "see her like this. She watched"
# "I know what in said on" <> "I know what is said on"
# "the isand. Loore tongues" <> "the island. Loose tongues"
# "canaria is certainly" <> "Canaria is certainly"
# "a paradise, but it has" <> "a paradise, but it has"
# "its serpents too. "" <> "its serpents too. ""
# "wag here just as they do" <> "wag here just as they do"
# "everywhere else. Grand" <> "everywhere else. Grand"
# "discovered chocolate wasthe same in both" <> "discovered chocolate was the same in both"
# "Soon thCy were chattering away gaily" <> "Soon they were chattering away gaily."
# "languages." <> "languages."
# ""O helado," surgled Pepita as the maid brougnt" <> ""El helado," gurgled Pepita as the maid brought"
# "They both thought it quite frhnry when they" <> "They both thought it quite funny when they"
# "ont two glass dishes. "ke-crcam,"Julia insisted." <> "out two glass dishes. "Ice-cream," Julia insisted."
# "hoarse, oynical voice. He removel" <> "hoarse, cynical voice. He removed"
# "erampped position was almost" <> "cramped position was almost"
# "exhilarating." <> "exhilarating."
# ""Had a nice ride?" he ashed in a" <> ""Had a nice ride?" he asked in a"
# "sensotion Sreedom from her" <> "sensation of freedom from her"
# "the gaf a utied her legs. The suddun" <> "the gag a untied her legs. The sudden"
# "But it was impcssible to" <> "But it was impossible to"
# "her cut into her wrists and" <> "her cut into her wrists and"
# "mouth." <> "mouth."
# "a beauetiful Mediterranean" <> "a beautiful Mediterranean"
# "ankles; the gag # hurt her" <> "ankles; the gag # hurt her"
# "with which he had bound" <> "with which he had bound"
# "night with a full moon, a" <> "night with a full moon, a"
# "stars were shining brightly." <> "stars were shining brightly."
# "feel amused for the cord" <> "feel amused for the cord"
# "She saw that it was" <> "She saw that it was"
# "blue black sky, and the" <> "blue black sky, and the"
# "hard across the face, but in her" <> "hard across the face, but in her"
# ""No," she shrieked and pushed the" <> ""No," she shrieked and pushed the"
# "present State of nervous tension" <> "present State of nervous tension"
# "she scarcely felt it." <> "she scarcely felt it."
# "glass away from her. He hit her" <> "glass away from her. He hit her"
# "ranout of fuel. I had to" <> "ran out of fuel. I had to"
# ""I happened to have the" <> ""I happened to have the"
# "the obvious suspect." <> "the obvious suspect."
# "protect myself, and Ray was" <> "protect myself, and Ray was"
# "lighter in my pocket. I borrowed" <> "lighter in my pocket. I borrowed"
# "it ages ago when my oun lighter" <> "it ages ago when my own lighter"
# "they would suspect nothing." <> "they would suspect nothing."
# "Ray And Sarah were" <> "Ray And Sarah were"
# "if they were still awake" <> "if they were still awake"
# "of stealing her jewellery." <> "of stealing her jewellery."
# "her beach because she had" <> "her beach because she had"
# "come upon him in the act." <> "come upon him in the act"
# "suppose he had murdered" <> "suppose he had murdered"
# "It seemed reasonable to" <> "It seemed reasonable to"
# "also acustomed to it. Even" <> "also accustomed to it. Even"
# "her. "My darling! She saiss something" <> "her. "My darling! She says something"
# "to me. ""I 'm All right, Pay,"" <> "to me." "I 'm All right, Ray,""
# "She must have passed out for the next" <> "She must have passed out for the next"
# "she murmured." <> "she murmured."
# "thing she knew he was shaking." <> "thing she knew he was shaking"
# "her? Depend he know that" <> "her? Depend he know that"
# "been, Sarah was equally in danger." <> "been, Sarah was equally in danger."
# "him to abduct her in this way" <> "him to abduct her in this way"
# "with the oobvious purpose of killing" <> "with the obvious purpose of killing"
# "But that had finally promted" <> "But what had finally prompted"
# "she had Greta's clip? But if he had" <> "she had Greta's clip? But if he had"
# "found the bullet will be traced" <> "found the bullet will be traced"
# "I 'le jump. And when my body is" <> "I 'll jump. And when my body is"
# ""You 'll have to shoot me before" <> ""You 'll have to shoot me before"
# "back to your gun." <> "back to your gun."
# "Countess Doriana?" Card asked." <> "Countess Doriana?" Carol asked."
# "and found me at the job." <> "and found me at the job."
# "either. " Nhy did you kill the" <> "either. "Why did you kill the"
# ""She came home earlfrom theparty" <> ""She came home early from the party"
# "Ray won't hove any proof" <> "Ray won't have any proof"
# "about the clip. But you suspected" <> "about the clip. But you suspected"
# "me befsre that, didn't you?" <> "me before that, didn't you?"
# "know you "ve put two and tug" <> "know you 've put two and two"
# "ton're not a foo. I" <> "You 're not a fool. I"
# "fogether ever since the child told you" <> "together ever since the child told you"
# "frout door. But when she tried" <> "front door. But when she tried"
# "to close it after her a foot" <> "to close it after her a foot"
# "was forced in the open doorway." <> "was forced in the open doorway."
# "foyer befove she reached the" <> "foyer before she reached the"
# "Grant 's suspicions by hen" <> "Grant's suspicions by her"
# "the staircase. There was only" <> "the staircase. There was only"
# "She had already aroused" <> "She had already aroused"
# "a short distance through the" <> "a short distance through the"
# "questions. She went quietly down" <> "questions. She went quietly down"
# "Grota. She blinked up at the stars and" <> "Greta. She blinked up at the stars and"
# "through iillages or towns." <> "through villages or towns."
# "her any more mercy than he had shown" <> "her any more mercy than he had shown"
# "she didn't think that Grant would show" <> "She didn't think that Grant would show"
# "occasionally she saw lights and heard" <> "occasionally she saw lights and heard"
# "traffic as though they were passing" <> "traffic as though they were passing"
# "know the truth?" <> "know the truth?"
# "quilt. He asked almost wildly, "Bat how" <> "guilt. He asked almost wildly, "But how"
# "an I let you live, knowing that you" <> "can I let you live, knowing that you"
# "If you kill me, as far as Jimny is" <> "If you kill me, as far as Jimmy is"
# "concernedit will be a definite proof of your" <> "concerned it will be a definite proof of your"
# "catching up with him to be" <> "catching up with him to be"
# "me. I had him in sight until he" <> "me. I had him in sight until he"
# "temporarly. I was too intent on" <> "temporarly. I was too intent on"
# "Grande Corniche I lost him" <> "Grande Corniche I lost him"
# "aware that another car was following" <> "aware that another car was following"
# "But when he started up the" <> "But when he started up the"
# "disappeared down the side road." <> "disappeared down the side road."
# "A shot rang out. He lurched and" <> "A shot rang out. He lurched and"
# "And then suddenly it happened." <> "And then suddenly it happened."
# "gave a cry and duopped" <> "gave a cry and dropped"
# "beside her." <> "beside her."
# "She fell sprawling at his feet." <> "She fell sprawling at his feet."
# "Aer legs collapsed under her." <> "Her legs collapsed under her."
# "She set hon lips firly." <> "She set her lips firmly."
# "gless ant of the glore" <> "glass out of the glove"
# "You go oven. He took a flask" <> "you go over. He took a flask"
# "from his posket and got a" <> "from his posket and got a"
# "compartment of the car." <> "compartment of the car."
# "You 'll be unconsciaus by the time" <> "You 'll be unconscious by the time"
# "we?" You 're going over the edge, "he said"" <> "me?" You 're going over the edge, "he said.""
# "This is the highest point on the Grande" <> "This is the highest point on the Grande"
# "Sarah had had. "What are you going to do with" <> "Sarah had had. "What are you going to do with"
# "Corniche." <> "Corniche."
# "Carole shuddered, remembering the drean" <> "Carol shuddered, remembering the dream"
# ""Keep going," Grant said in a" <> ""Keep going," Grant said in a"
# "the gag in her mouth and he held" <> "the gag in her mouth and he"
# "low harsh voice. Don't hid yourself" <> "low harsh voice. Don't kid yourself"
# "revolver; it 's my life or yours." <> "revolver; it 's my life or yours"
# "She couldn't scream because of" <> "She couldn't scream because of"
# "both her hands tightly behind her" <> "held both her hands tightly behind her"
# "I 'll be timid about using this" <> "I 'll be timid about using this"
# "back." <> "back."
# "fourished in the days of Judah." <> "flourished in the days of Judah."
# "in the court of Shem which" <> "in the court of Shem which"
# "han? This proves, according to the Gemarg," <> "man? This proves, according to the Gemara,"
# "But howr could he have known this," <> "But how could he have known this,"
# "perhaps she had consorted withsome other" <> "perhaps she had consorted with some other"
# "that the holy spirit manifested itself" <> "that the holy spirit manifested itself"
# "worn out in saying:" <> "worn out in saying:"
# "(Heb beli dai? Rami Bar Rabh" <> "(Heb beli dai? Rami Bar Rabh"
# "replies:"Until your lips are" <> "replies :" Until your lips are"
# "This is the verse: The Gemara" <> "This is the verse: The Gemara"
# "then asks: " What is the meaning" <> "then asks: "What is the meaning"
# "of"more than sufficiency"." <> "of" more than sufficiency ""
# "have been used because the whole" <> "have been used because the whole"
# "to in the singular, as they ave" <> "to in the singular, as they are"
# "from the text quoted. With regard" <> "from the texts quoted. With regard"
# "Raba objects that there is no proof" <> "Raba objects that there is no proof"
# "which said:" She is his mother."" <> "which said: "She is his mother.""
# "in another verse." <> "in another verse."
# "people of Israel are referred" <> "people of Israel are referred"
# "to Samual the singular form may" <> "to Samuel the singular form may"
# "But it was a heavenly voice" <> "But it was a heavenly voice"
# "Evenmore significant is the fact" <> "Even more significant is the fact"
# "that the proof texts from Bory and" <> "that the proof texts from Boaz and"
# "anormous Mishuch." <> "anonymous Mishnah."
# "the angel ne quoted, in spport of this" <> "the angel are quoted, in support of this"
# "rery thesis that greefing should be" <> "very thesis that greeting should be"
# "jiven by the divine name, in an" <> "given by the divine name, in an"
# "there is no proof of divine approval," <> "there is no proof of divine approval,"
# "The question is then asked:" <> "The question is then asked:"
# "of greeting." <> "of greeting."
# "only that Bouz used this form" <> "only that Boaz used this form"
# "from the verse dealing with Bouz" <> "from the verse dealing with Boaz"
# "To this the reply is given that" <> "To this the reply is given that"
# "Answer: (4). Third proof text." <> "Answer: (4). Third proof text."
# "Question: What is the meaning" <> "Question: What is the meaning"
# "Boaz B). Angle. Question:" <> "Boaz. (B). Angel. Question:"
# "of beli dai?" <> "of beli dai?"
# "(3). Second proof text. (A)." <> "(3). Second proof text. (A)."
# "a sugya has fashioned from" <> "a sugya has been fashioned from"
# "Form the abve it" <> "From the above it"
# "follows that, once again, we" <> "follows that here, once again, we"
# "built around the saying of R. Joshua" <> "built around the saying of R. Joshua"
# "of the redactors. The sugya is" <> "of the redactors. The sugya is"
# "material already in the hands" <> "material already in the hands"
# "have a good illustration of how" <> "have a good illustration of how"
# "b. Levi." <> "b. Levi."
# ""They established it and the Jews took it" <> ""They established it and the Jews took it"
# "here below."" <> "here below.""
# "(the reading of the book of Esther) down" <> "(the reading of the book of Esther) down"
# "It heheavenly court) established above" <> "(the heavenly court) established above"
# "apon them". This is said to mean: "They" <> "upon them". This is said to mean: "They"
# "that which the Jews took upon them" <> "that which the Jews took upon them"
# "Rabh there is no reason why" <> "Rabh there is no reason why"
# "replies by referring his master" <> "replies by referring his master"
# "an objection and Abaye" <> "an objection and Abaye"
# "here is that if Rabh Joseph" <> "here is that if Rabh Joseph"
# "Levi. The only difficulty" <> "Levi. The only difficulty"
# "to the saying of R. Joshua b." <> "to the saying of R. Joshua b."
# "To this Rabh Joseph raises" <> "To this Rabh Joseph raises"
# "he should not disagree." <> "he should not disagree."
# "is prepared to disagree with" <> "is prepared to disagree with"
# "which they are quoted in the" <> "which they are quoted in the"
# "dicussion on the Mishuah. Or" <> "discussion on the Mishnah. Or"
# "other sugya." <> "other sugya."
# "answer and this is quoted in the" <> "answer and this is quoted in the"
# "contaims the origimal question and" <> "contains the original question and"
# "with regard to the meed for the" <> "with regard to the need for the"
# "here im the same words im" <> "here in the same words in"
# "it is possible that our sugya" <> "it is possible that our sugya"
# "The qucestion and answer" <> "The question and answer"
# "test of the angel ave quoted" <> "text of the angel are quoted"
# "The verb is parallel to test and" <> "The verb is parallel to test and"
# "trying and experimenting. The typical" <> "trying and experimenting. The typical"
# "must be taken in this sense of" <> "must be taken in this sense of"
# "of pleasure but the reverse. We" <> "of pleasure but the reverse. We"
# "Hebrew view of life is not a denial" <> "Hebrew view of life is not a denial"
# "mind." <> "mind."
# "quest that Qoheleth had in" <> "quest that Qoheleth had in"
# "need to remember the particular" <> "need to remember the particular"
# "water supply. The pools are" <> "water supply. The pools are"
# "The word is used in the" <> "The word is used in the"
# "Singuloo in Neh 2.0 and" <> "singular in Neh 2.8 and"
# "natrual transition" <> "natrual transition"
# "to the vital question of" <> "to the vital question of"
# "S. of Sol. 4.13. 6. A" <> "S. of Sol. 4.13. 6. A"
# "from germans and orchard," <> "from germans and orchards"
# "posibly natural." <> "posibly natural."
# "to be the source both of fresh-" <> "to be the source both of fresh-"
# "underwarld, which was thought" <> "underworld, which was thought"
# "not satisfied ... hor the ear" <> "not satisfied ... nor the ear"
# "water oceans." 9. The eye is" <> "water oceans." 9. The eye is"
# "The references is to "the" <> "The references is to "the"
# "filled." <> "filled."
# "water springs and of the salt-" <> "water springs and of the salt-"
# "literary device was really a means of" <> "literary device was really a means of"
# "expressing Qoheleth's conviction that" <> "expressing Qoheleth's conviction that"
# "The author clearly intends to be" <> "The author clearly intends to be"
# "taken as Solomon. The use of this" <> "taken as Solomon. The use of this"
# "the clue to the final meaning of life." <> "the clue to the final meaning of life."
# "12. I The preacher have" <> "12. I The preacher have"
# "been king over bsrael in Jerusalem." <> "been king over Israel in Jerusalem."
# "neither wealth nor wisdom prouided" <> "neither wealth nor wisdom provided"
# "The word for toil is" <> "The word for toil is"
# "of communication in the" <> "of communication in the"
# "Under the sun. It means" <> "Under the sun. It means"
# "vexation. This is the problem" <> "vexation. This is the problem"
# "ulso used of sorrow and" <> "also used of sorrow and"
# "modern industrial World. 3." <> "modern industrial World. 3."
# "simply "alive"." <> "simply "alive"."
# "To cheer my body" <> "To cheer my body"
# "cf 1 Sam 21.14;" <> "cf 1 Sam 21.14;"
# "50;48; 51.7. 3." <> "50;48; 51.7. 3."
# "my flesh with wine "." <> "my flesh with wine"."
# "Jer 25. 16; 46.9;" <> "Jer 25.16; 46.9;"
# "with wine. Lit 'To draw" <> "with wine. Lit "To draw"
# "The phrasc is chfficult." <> "The phrase is difficult."
# "8. Ahy who nad been before" <> "8. Any who had been before"
# "me in Jerusalem." <> "me in Jerusalem."
# "building operations." <> "building operations."
# "sition of the scale of his" <> "sition of the scale of his"
# "7. I bought male and female" <> "7. I bought male and female"
# "slaves. The acquisition of slaves" <> "slaves. The acquisition of slaves"
# "would be the necessang presuppo-" <> "would be the necessary presuppo-"
# "Close to the building projects" <> "Close to the building projects"
# "works. Lit "I made great my works"." <> "works. Lit "I made great my works"."
# "(1 Kings 4.25, S. of Sol. 8. 11)." <> "(1 Kings 4.25; S. of Sol. 8.11)."
# "dillettante. 4. I made great" <> "dillettante. 4. I made great"
# "would be the vineyards" <> "would be the vineyards"
# "Here is no armchair doctoinaie" <> "Here is no armchair doctrinaire"
# "precisely. The finishing line is" <> "precisely. The finishing line is"
# "surl gets nowhere! 6. The wind blows ..." <> "sun gets nowhere! 6. The wind blows ..."
# "contimally found to be buet the" <> "continually found to be but the"
# "The thourght fits Qoheleths poxition" <> "The thought fits Qoheleth's position"
# "the windl returns." <> "the wind returns."
# "prelude to the starting post - the" <> "prelude to the starting post - the"
# "The literal meaning is "a" <> "The literal meaning is "a"
# "teeding on the wind". The" <> "feeding on the wind". The"
# "of the writer and it is ased" <> "of the writer and it is used"
# "feeding thei flocks." <> "feeding their flocks."
# "some seven tines in this book." <> "some seven times in this book."
# "whe is aces of shepherds" <> "word is used of shepherds"
# "This is a favourite phrase" <> "This is a favourite phrase"
# "is "to twist or pervert"." <> "is "to twist or pervert"."
# "its final significance is concerned," <> "its final significance is concerned,"
# "All human activity, as far as" <> "All human activity, as far as"
# "the shadowy insubstantial air. 15. What" <> "the shadowy insubstantial air. 15. What"
# "is like feeding on the wiA or disiring" <> "is like feeding on the wind or desiring"
# "is crooked. The root meaning of crooked" <> "is crooked. The root meaning of crooked"
# "9; 1.2). It carries the idea of reward" <> "9; 11.2). It carries the idea of reward"
# "Qoheleth (of 2. Hl; 3. 22; S. I8 ff; 9.6," <> "Qoheleth (cf 2.21; 3.22; 5.18 ff; 9.6,"
# "experience." <> "experience."
# "or profit. Qoheleth is suggesting that" <> "or profit. Qoheleth is suggesting that"
# "there is a gain from human" <> "there is a gain from human"
# "This is a farourite word with" <> "This is a favourite word with"
# "4. I said to myself. Lit" <> "16. I said to myself. Lit"
# "Thesew two terms are frequently" <> "These two terms are frequently"
# "heart. All whe were over Jerusalem" <> "heart. All who were over Jerusalem"
# ""I, Personally, spoke with my" <> ""I, Personally, spoke with my"
# "before me. Wisdom and knowledge." <> "before me. Wisdom and knowledge."
# "found in close association." <> "found in close association."
# "is used as a technical" <> "is used as a technical"
# "by "enquiring of the Lord"." <> "by "enquiring of the Lord"."
# "The original for search out" <> "The original for search out"
# "and is what is meant" <> "and is what is meant"
# "Search ont in wisdom." <> "Search out in wisdom."
# "priest or the prophet" <> "priest or the prophet"
# "term for consulting the" <> "term for consulting the"
# "madness means "mad revelry" <> "madness means "mad revelry"
# "and wickedness". The quest for" <> "and wickedness". The quest for"
# "The world translated" <> "The world translated"
# "AV, I will prove three with mirth." <> "AV, I will prove thee with mirth."
# "1. Iwill make a test of pleasure." <> "1. I will make a test of pleasure."
# "pleasure and material satisfaction." <> "pleasure and material satisfaction."
# "the present through his being" <> "the present through his being"
# "of present reality in remembering" <> "of present reality in remembering"
# "remembered. There is an element" <> "remembered. There is an element"
# "personality of a man continnes into" <> "personality of a man continues into"
# "- the past is re-presented." <> "- the past is re-presented."
# "The act meaus more than the" <> "The act means more than the"
# "recalling of past events. The rery" <> "recalling of past events. The very"
# "system." <> "system."
# "of the strihe notices. For the" <> "of the strike notices. For the"
# "The Conference could" <> "The Conference could"
# "the lrague: "We wish to negotiate" <> "the league: "We wish to negotiate"
# "players' leaders are keen totell" <> "players' leaders are keen to tell"
# "end in, at least, a postponement" <> "end in, at least, a postponement"
# "form of the retain and trausfer" <> "form of the retain and transfer"
# "on one of yours ideas - an eased" <> "on one of yours ideas - an eased"
# "them on D0per cent. Commission to" <> "them on 10 per cent. Commission to"
# "began to speecialise in contributions." <> "began to specialise in contributions."
# "periodicals, books, broadcasts," <> "periodicals, books, broadcasts,"
# "by well-known sportsmen. He enrolled" <> "by well-known sportsmen. He enrolled"
# "and advertising." <> "and advertising."
# "His name? Denis Compton. Eleven" <> "His name? Denis Compton. Eleven"
# "years ago the enterprsing Mr. Harvey" <> "years ago the enterprising Mr. Harvey"
# "Bageenal Harvey is the name." <> "Bagenal Harvey is the name."
# "His partner sat opposite him." <> "His partner sat opposite him."
# "endorse articles for newspapers," <> "endorse articles for newspapers,"
# "Capsized. He should have an easy task" <> "Capsized. He should have an easy task"
# "he never succeeded." <> "he never succeeded."
# "Tokoroa over hurdles, but in six encounters" <> "Tokoroa over hurdles, but in six encounters"
# "in the last event. Retour De Flamme for the" <> "in the last event. Retour De Flamme for the"
# ""replay". By Peter Or sullevan. Retour De" <> ""replay". By Peter O'Sullevan. Retour De"
# "Flamme was frequently backed to beat" <> "Flamme was frequently backed to beat"
# "Office hung pictures of sport-" <> "Office hung pictures of sport-"
# "legal and other advisers much" <> "legal and other advisers much"
# "ing, salebrities signed in"" <> "ing celebrities signed in""
# "His business. "Jimmy has" <> "His business. "Jimmy has"
# "I am On the walls of his" <> "I am. On the walls of his"
# "many thanks "terms." <> "many thanks "terms."
# "better qualified to help him than" <> "better qualified to help him than"
# "more, I don't want to. "A strike's" <> "more, I don't want to. "A strike 's"
# "the last thing I want." <> "the last thing I want."
# "I can't make a club pay a" <> "I can't make a club pay a"
# "I can't make player' contract" <> "I can't make players' contract"
# "player so much a week. And, what 's" <> "player so much a week. And, what 's"
# "number of players ould be in" <> "number of players would be in"
# "He added: "But I am not guing" <> "He added: "But I am not going"
# "any one season, only a small" <> "any one season, only a small"
# "That isn't so. At the end of" <> "That isn't so. At the end of"
# "to waste time." <> "to waste time."
# "a position to ask fora more." <> "a position to ask for a move."
# "drinking coffee in the back of his" <> "drinking coffee in the back of his"
# "man behind the strike." <> "man behind the strike."
# "modest Charterhouse-street, London," <> "modest Charterhouse-street, London,"
# "Office. Mr. X, accused by football league" <> "Office. Mr. X, accused by football league"
# "secretary Alan Hardaker as being the" <> "secretary Alan Hardaker as being the"
# "editor. The mysterious Mr. X sat" <> "editor. The mysterious Mr. X sat"
# "By Robert Findlay. The sperts" <> "By Robert Findlay. The sports"
# "handicap - as connections hope Nerganser" <> "handicap - as connections hope. Merganser"
# "is confident of a bold oid by Miss Popsi" <> "is confident of a bold bid by Miss Popsi"
# "The blot? He wauld prove a blot on the" <> "The blot? He could prove a blot on the"
# "W-issi." <> "Wopsi."
# "Also scems well treated, and Johnny lehane" <> "Also seems well treated, and Johnny Lehane"
# "player for years. Cheung called inat" <> "player for years. Cheung called in at"
# "left agaiust Wolfcs today. "I 'e" <> "left against Wolfes today. "I 've"
# "cneung from China" <> "Cheung From China"
# "Not sera such a perfectly balaned" <> "Not seen such a perfectly balanced"
# "to Rome, where he was lue to" <> "to Rome, where he was due to"
# "Blackpool last sunmwer on lus way" <> "Blackpool last summer on his way"
# "faes hk ires By Meike Laygley." <> "faces he ' es. By Mike Langley."
# "Htc is Blackpool's outside outside" <> "He is Blackpool's outside outside"
# "play for Formosa in the Olympics." <> "play for Formosa in the Olympics."
# "your garden. By Percy Thrower, M.D.H." <> "your garden. By Percy Thrower, M.D.H."
# "Flowors. We are now at the beginning" <> "Flowers. We are now at the beginning"
# "Afterwards they should romp" <> "Afterwards they should romp"
# "and roses" <> "and roses."
# "of the planting season for trees, shrubs" <> "of the planting season for trees, shrubs"
# "away in spring. This week in" <> "away in spring. This week in"
# "and for a South or west-facing wall," <> "and for a South or west-facing wall,"
# "conditiun until the end of March. For a" <> "condition until the end of March. For a"
# "planting season and work can continue" <> "planting season and work can continue"
# "at any time whent soil is in reasonable" <> "at any time when the soil is in reasonable"
# "for an East wall a plum or greengage" <> "for an East wall a plum or greengage"
# "Fruit. For fruit also this is the ideal" <> "Fruit. For fruit also this is the ideal"
# "North wull I recommend a Morello cherry," <> "North wall I recommend a Morello cherry,"
# "a pead nectarine or apritot." <> "a peach, nectarine or apricot."
# "When greenhouse plants go to rest." <> "When greenhouse plants go to rest."
# "mean that they need no attention" <> "mean that they need no attention"
# "S. Clapham. Juring the winter the" <> "S Clapham. During the winter the"
# "summer-flowering greenhouse perennials" <> "summer-flowering greenhouse perennials"
# "are of course at rest, but this does not" <> "are of course at rest, but this does not"
# "at all." <> "at all."
# "It is not, in general, tise to move" <> "It is not, in general, wise to move"
# "are also safer with some protection." <> "are also safer with some protection."
# "herbaceous plants in te middle of the" <> "herbaceous plants in the middle of the"
# "winter. This is true of some veronicas" <> "winter. This is true of some veronicas"
# "escallonias. In northern and eastern" <> "escallonias. In northern and eastern"
# "and also of the larger flowered" <> "and also of the larger flowered"
# "districts the large flowerad hy drangeas" <> "districts the large flowered hydrangeas"
# "once they are in." <> "once they are in."
# "particularly where a soreen of" <> "particularly where a screen of"
# "But Cupressus lawsoniana and" <> "But Cupressus lawsoniana and"
# "Thuja plicat- make fine hedges," <> "Thuja plicata make fine hedges,"
# "for the planting of trees, shrp'i's" <> "for the planting of trees, shrubs"
# "because these are permanent" <> "because these are permanent"
# "faire size is required. The preparation" <> "fair size is required. The preparation"
# "plants which cannot be disturbed" <> "plants which cannot be disturbed"
# "and roses should alnays be thorough" <> "and roses should always be thorough"
# "theve is nothing settor than" <> "there is nothing better than"
# "heavy land in antumn becwuse" <> "heavy land in autumn because"
# "winter # so that frost, wind" <> "winter # so that frost, wind"
# "the lummps of clay." <> "the lumps of clay."
# "at least to the full depth of a" <> "at least to the full depth of a"
# "is panticulargy important to dig" <> "is particularly important to dig"
# "and vain may brewh # up. It" <> "and rain may break it up. It"
# "All grourd should then be dug" <> "All ground should then be dug"
# "frost ane wind to break down" <> "frost and wind to break down"
# "spade and left rogh duving the" <> "spade and left rough during the"
# "on a shelf near the glass and" <> "on a shelf near the glass and"
# "spring as I find that the" <> "spring as I find that the"
# "finer plants than thoose rooted" <> "finer plants than thoose rooted"
# "These I shall now put" <> "These I shall now put"
# "shall take further cutting in" <> "shall take further cutting in"
# ...
# "The duke 's trigger-finger and the" <> "The duke's trigger-finger and the"
# "performances as tiger and rhino hunts" <> "performances as tiger and rhino hunts"
# "ritual slaughter of beasts have taken the" <> "ritual slaughter of beasts have taken the"
# "tour has been an immense success. The" <> "tour has been an immense success. The"
# "were dropped from futurs Royal programmes." <> "were dropped from future Royal programmes."
# "Qneen has won a triumph. It would be" <> "Queen has won a triumph. It would be"
# "headlines in this country. Nerertheless, the" <> "headlines in this country. Nevertheless, the"
# "pleasanter if such cruel and fendal" <> "pleasanter if such cruel and feudal"
# "Cong-." <> "Congo."
# "Iard as of peace. The" <> "hard way of peace. The"
# "that the allert readers of the" <> "that the allert readers of the"
# "We publish it in the belief" <> "We publish it in the belief"
# "has saffered, juve injury in the" <> "has suffered grave injury in the"
# "herild will not be beguiled by" <> "herald will not be beguiled by"
# "authoritn of the Uuited nations" <> "authority of the United nations"
# "this kind of soft-soap. The" <> "this kind of soft-soap. The"
# "wealth Prime Mrnister will." <> "wealth Prime Ministers will"
# "It may be that the Common-" <> "It may be that the Common-"
# "Expulsion? There is no" <> "Expulsion? There is no"
# "fied the actions of the Natio-" <> "fied the actions of the Natio-"
# "nalists. On the contrary," <> "nalists. On the contrary,"
# "decide against this fial step." <> "decide against this final step."
# "apartheid is being applied" <> "apartheid is being applied"
# "ever more ruthlessly." <> "ever more ruthlessly."
# "evidence that the policy." <> "evidence that the policy"
# "of appeasement has modi-" <> "of appeasement has modi-"
# "That is not a ceremonial duty, and the" <> "That is not a ceremonial duty, and the"
# "politictans unless they see it through. That" <> "politicians unless they see it through. That"
# "soldiers have every right to blame the" <> "soldiers have every right to blame the"
# "providing 3,noo men, who must take about" <> "providing 3,000 men, who must take about"
# "a fortoight to airive." <> "a fortnight to arrive."
# "made. India has responded handsomely by" <> "made. India has responded handsomely by"
# "was the first point that Mr. Hammarskjold" <> "was the first point that Mr. Hammarskjold"
# "mission could have spoken of" <> "mission could have spoken of"
# "that he is not being hypocritical." <> "that he is not being hypocritical ."
# "what he regards as a divine" <> "what he regards as a divine"
# "the impenetrable cocoon of" <> "the impenetrable cocoon of"
# "aportheid as "a policy of good" <> "apartheid as "a policy of good"
# "Africans" <> "Africans"
# "neigbbourliness." We mgy be sure" <> "neighbourliness ." We may be sure"
# "A good neighbour to those" <> "A good neighbour to those"
# "That is what he really believes." <> "That is what he really believes ."
# "ONLY a man wrapped in" <> "ONLY a man wrapped in"
# "uselessly locked up because" <> "uselessly locked up because"
# "There they have stayed" <> "There they have stayed"
# "and choke off speculatiom" <> "and choke off speculation"
# "against dollar and pound?" <> "against dollar and pound?"
# "to correct Germany's" <> "to correct Germany's"
# "massive trading surplus" <> "massive trading surplus"
# "cralnation be enongh" <> "valuation be enough"
# "erough? Will the new" <> "enough? Will the new"
# "of trading abroad. Is it" <> "of trading abroad. Is it"
# "Germany has no tradition" <> "Germany has no tradition"
# "Hammarskjold is determined, they" <> "Hammarskjold is determined, they"
# "must go. The best news for the" <> "must go. The best news for the"
# "Congo would be agreemeat betareen" <> "Congo would be agreement between"
# "were not required. But back, Mr." <> "were not required. But back, Mr."
# "its rival political be hee." <> "its rival political be lee."
# "awway again, satisfied that they" <> "away again, satisfied that they"
# "Yesterday the ships turned" <> "Yesterday the ships turned"
# "South Africa. Will it end" <> "South Africa. Will it end"
# "fru 'he Lommonwealtl? The" <> "from the Commonwealth? The"
# "be settled at this conference." <> "be settled at this conference."
# "wit, South Africo's exclusion" <> "with South Africa's exclusion"
# "Editorial. Dilemma of" <> "Editorial. Dilemma of"
# "is a possibility that it will not" <> "is a possibility that it will not"
# "is. # is "ouch and go. There" <> "is. # is "ouch and go. There"
# "It was Dr. Verwoerd who" <> "It was Dr. Verwoerd who"
# "It is impossible to make contact with" <> "It is impossible to make contact with"
# ""defile" the National white stock." <> ""defile" the National white stock."
# "hd Pa rotest against admitting any" <> "led a protest against admitting any"
# "o them because they would" <> "of them because they would"
# "Dr. Verwoerd in his nightmare World." <> "Dr. Verwoerd in his nightmare World."
# "on the Cowwonwealth Conference in hondon. Will it" <> "rise on the Commonwealth Conference in London. Will it"
# "end with" <> "end with"
# "revulsiou agamst the South Africon Governwout's" <> "revulsion against the South African Government's"
# "policy of apartheid as we wait for the curtain to nse" <> "policy of apartheid as we wait for the curtain to"
# "Priwe Minister after Prwe Minister speaks out in" <> "Prime Minister after Prime Minister speaks out in"
# "failing until now to" <> "failing until now to"
# "imports." <> "imports ."
# "she has been growing by" <> "she has been growing by"
# "exports much more than she" <> "exports much more than she"
# "nation should. Germany" <> "nation should . Germany"
# "deliberately encouraging more" <> "deliberately encouraging more"
# "Booming Germany is" <> "Booming Germany is"
# "also aware how t unpopular" <> "also aware how # unpopular"
# "rising prices at home. She is" <> "rising prices at home . She is"
# "co-operate as a ceditor" <> "co-operate as a creditor"
# "imports as a means to crb" <> "imports as a means to curb"
# "wituess ro what Christianity really" <> "witness to what Christianity really"
# "whar, in fact, can the other" <> "what , in fact , can the other"
# "this gallant" <> "this gallant"
# "Commonwealth , ounhries do to" <> "Commonwealth countries do to"
# "The view of the Archbsishoy," <> "The views of the Archbishop ,"
# "bring support and comfort to" <> "bring support and comfort to"
# "means, mst carry weight. But" <> "means , must carry weight . But"
# "who hnas maintained an unflinching" <> "who has maintained an unflinching"
# "be against the interests of the Africans." <> "be against the interests of the Africans."
# "long been a courageous fighter against" <> "long been a courageous fighter against"
# "Capetown has shown that the matter" <> "Capetown has shown that the matter"
# "A mistake. The Archbishop of" <> "A mistake. The Archbishop of"
# "attention. In his view it would also" <> "attention. In his view it would also"
# "is not clea-cut. The Archbishop has" <> "is not clear-cut. The Archbishop has"
# "apartheid. He must be heard with" <> "apartheid. He must be heard with"
# "in any of its countries is surely" <> "in any of its countries is surely"
# "survive. And this is a" <> "survive. And this is a"
# "citisens are coloured for every" <> "citizens are coloured for every"
# "policy of racial discrimination" <> "policy of racial discrimination"
# "one who is white." <> "one who is white."
# "Wider picture. The Commonwealth" <> "Wider picture. The Commonwealth"
# "Commonwealth in which five" <> "Commonwealth in which five"
# "the one thing that it could not" <> "the one thing that it could not"
# "is multi-racial society. A" <> "is multi-racial society. A"
# "out of the way." <> "out of the way."
# "hardly anything is done to bring" <> "hardly anything is done to bring"
# "Ministers meet in Washington tomorow" <> "Ministers meet in Washington tomorrow"
# "talks nearer. When the Western Foreign" <> "talks nearer. When the Western Foreign"
# "women who pride themselves" <> "women who pride themselves"
# "Time to start talking. Yet" <> "Time to start talking. Yet"
# "So may a few emancipated" <> "So may a few emancipated"
# "on their common sense." <> "on their common sense."
# "the first of these will be nearly" <> "the first of these will be nearly"
# "excpulsion, inchuding African" <> "expulsion , including African"
# "that could be excercised were" <> "than could be exercised were"
# "she cut off from it. On the" <> "she cut off from it . On the"
# "put on Douth Afuica while she" <> "put on South Africa while she"
# "other hand, thos. who favour" <> "other hand , those who favour"
# "than the" <> "than the"
# "remaims in the Commonueclth" <> "remains in the Commonwealth"
# "He holds that moe pressure can be" <> "He holds that more pressure can be"
# "beaders, foel that nothing less" <> "leaders , feel that nothing less"
# "not, perhaps, quite the impression" <> "not, perhaps, quite the impression"
# "Small nations would not" <> "Small nations would not"
# "remain free for long in this" <> "remain free for long in this"
# "that he intended." <> "that he intended."
# "World if the UN was not" <> "World if the UN was not"
# "made a strong impression. But" <> "made a strong impression. But"
# "their bulwark. The smile on" <> "their bulwark. The smile on"
# "the face of Verwoerd. He has" <> "the face of Verwoerd. He has"
# "a ball is not covered by the" <> "a ball is not covered by the"
# "Sally" at a local garden fete" <> "Sally "at a local garden fete"
# "industrial inguries act."-" <> "industrial injuries act." -"
# "who volunteers to be an" Aunt-" <> "who volunteers to be an" Aunt-"
# "and eets a clout on the lar with" <> "and gets a clout on the ear with"
# "Ed. Footnote. "No. A man" <> "Ed. Footnote. "No. A man"
# "socialist demooracy this is a habit we" <> "socialist democracy this is a habit we"
# "Francis Williams, "used to be a" <> "Francis Williams, "used to be a"
# ""Book reading," wrote" <> ""Book reading," wrote"
# "socialist habit. To secuve an educated" <> "socialist habit. To secure an educated"
# "should indulge in as we did years" <> "should indulge in as we did years"
# "ago."" <> "ago.""
# "these items were 22 to," <> "these items were 22 ,"
# "Labour supporters on" <> "Labour supporters on"
# "(The percentages among" <> "(The percentages among"
# "3o and 7o rispectively.)" <> "30 and 7 rispectively .)"
# "A common view. If fairly" <> "A common view. If fairly"
# "common view was that." <> "Common view was that."
# "By Frahk Horrabin. France-" <> "By Frank Horrabin. France -"
# "she had agreed to the British" <> "she had agreed to the British"
# "year or two." <> "year or two."
# "established a protectorate over" <> "established a protectorate over"
# "seizure of Cyprus. Five years ago" <> "seizure of Cyprus. Five years ago"
# "the congress of Berlin, at which" <> "the congress of Berlin, at which"
# "independent- thus anticipating" <> "independent - thus anticipating"
# "Tunisia in 1881, three years after" <> "Tunisia in 1881, three years after"
# "Cin 1956) Tunisia became" <> "(in 1956) Tunisia became"
# "the freeing of cyprus by a" <> "the freeing of Cyprus by a"
# "group that the choice of Governement rests." <> "group that the choice of Government rests."
# "change the Gouvernment. It is on this uncertain" <> "change the Gouvernment. It is on this uncertain"
# "reading." <> "reading."
# "I 's a grave thought. This book is worth" <> "It 's a grave thought. This Book is worth"
# "Three people inevery street changing over could" <> "Three people in every street changing over could"
# "the people." <> "the people."
# "splak for the great majority of" <> "speak for the great majority of"
# "against are fervently convinced they" <> "against are fervently convinced they"
# "of controversy about unilateral" <> "of controversy about unilateral"
# "effective and convincing. For example, since" <> "effective and convincing. For example, since"
# "Our general impression was" <> "Our general impression was"
# "that tho Labour programmes were the most" <> "that the Labour programmes were the most"
# "the election there have been months" <> "the election there have been months"
# "disarmament. Buth those for and" <> "disarmament. Both those for and"
# "Sid Woodruff started his" <> "Sid Woodruff started his"
# "reached the higher life." <> "reached the higher life."
# "pioneering work for labour when" <> "pioneering work for Labour when"
# "and lived in sordid sleums." <> "and lived in sordid slums."
# "living, people imagive they hae" <> "living, people imagine they have"
# "people were overvored, undesfed," <> "people were overworked, underfed,"
# "To-day, with a higher stardard of" <> "To-day, with a higher standard of"
# "History on film strip." <> "History on film strip."
# "s0 pictures." <> "30 pictures."
# "A pamphlet of notes on the" <> "A pamphlet of notes on the"
# "they which have the most pictures." <> "they which have the most pictures."
# "lecture is provided along with" <> "lecture is provided along with"
# "working-cll- circulations it is" <> "working-cll- circulations it is"
# "papers that have the biggest" <> "papers that have the biggest"
# "Besides, if one looks at the" <> "Besides, if one looks at the"
# "the film strip, which contains" <> "the film strip, which contains"
# "Buckle. What every guru knows." <> "Buckle. What every guru knows."
# ""Dance inspires him ceaselessly to" <> ""Dance inspires him ceaselessly to"
# "shining pinnade of perfedion that" <> "shining pinnacle of perfection that"
# "FAt. Ballef. Bby Richard" <> "F A. Ballet. By Richard"
# "is the goal of everyy artiste." <> "is the goal of every artiste."
# "strive higher and higher towards the" <> "strive higher and higher towards the"
# "Ricidha And Vosanti are graceful tor." <> "Radha And Vasanti are graceful, too."
# "-Verdi's sinplicity and hones." <> "- Verdi's simplicity and hones-"
# "whiusy and phantas magoria" <> "whimsy and phantasmagoria"
# "Alva and Signora Freni as" <> "Alva and Signora Freni as"
# "Somewhere in the course" <> "Somewhere in the course"
# "the prettiness, the slapstick and" <> "the prettiness, the slapstick and"
# "Great pleasure is given by Luigi" <> "Great pleasure is given by Luigi"
# "the young lovers." <> "the young lovers."
# "of all this - the clowning and" <> "of all this - the clowning and"
# "ty have farllen by the wayside." <> "ty have fallen by the wayside."
# "not consistently adopted." <> "not consistently adopted."
# "vigorously bul with a faulty" <> "vigorously but with a faulty"
# "sense of legato by the" <> "sense of legato by the"
# "ways of thought were, however," <> "ways of thought were, however,"
# "stirring choral scenes, sung" <> "stirring choral scenes, sung"
# "We lsh choir. Modern dic tion and" <> "Welsh choir. Modern diction and"
# "Both operas are full of" <> "Both operas are full of"
# "His Falstaff " though likely" <> "His "Falstaff," though likely"
# "versal. Visually, it is inventive" <> "versial. Visually, it is inventive"
# "and his followers." <> "and his followers."
# "near the beginning. If you can accept" <> "near the beginning. If you can accept"
# "the short opening scene between Falstaff" <> "the short opening scene between Falstaff"
# "and often lovely. The worst comes" <> "and often lovely. The worst comes"
# "to prove a hit, is again contro-" <> "to prove a hit, is again contro-"
# "old (yes) Indian boy in a" <> "old (yes) Indian boy in a"
# "happend to be a one-year-" <> "happend to be a one-year-"
# "Then he started dancing" <> "Then he started dancing"
# "white fur coat. Records. Hands" <> "white fur coat. Records. Hands"
# "looks with a neighbour who" <> "looks with a neighbour who"
# "again. And I exchanged" <> "again. And I exchanged"
# "and feet." <> "and feet."
# "sort of inn courtyard: striking." <> "sort of inn courtyard: striking."
# "deal. Thence to Ford's garden, a" <> "deal. Thence to Ford's garden, a"
# "Bowman could only rampaye and roister" <> "Bowman could only rampage and roister"
# "poor word, for they achieved a good" <> "poor word, for they achieved a good"
# "around the stage, though "only" is a" <> "around the stage, though "only" is a"
# "Michael Langdon And Robert" <> "Michael Langdon And Robert"

# %%
# TODO: Print words above also in `xyn` inference notebook!

# %%
df.groupby(['name', 'type']).mean()
# Out:
#                    value
# name      type
# inference cer   0.033374
#           wer   0.157067

# %%
df.groupby(['name', 'type']).mean()
# Out:
#                    value
# name      type
# inference cer   0.053571
#           wer   0.200000

# %% [markdown]
# Both metrics improved a bit after using the correct (=training) alphabet.
#
# However, the WER is still very bad; with CER being surprisingly good.
#
# Nevertheless, I conclude that inference on my own written text in Xournal does **NOT** work!
#
# Note that I confirmed the code to work by plugging in the IAM-OnDB dataset here which leads to reproducing the metrics as provided in `train` and `val` results reported above.

# %% [markdown]
# ## Hypothesis: The two datasets are very different and hence the performance on X++ is so bad

# %% [markdown]
# Difference here means the input tensor as segment lengths.

# %% [markdown]
# Hence, investigate the lengths of the differences:

# %%
def get_segment_lengths(dataloaders: list) -> list:
    results = []

    for dataloader in dataloaders:
        for sample in dataloader:
            batch_size = sample['ink'].shape[1]
            for i_sample_in_batch in range(batch_size):
                length = sample['ink_lengths'][i_sample_in_batch]
                dx, dy = sample['ink'][:length, i_sample_in_batch, [0, 1]].T
                segment_lengths = np.sqrt((dx**2 + dy**2))
                results += segment_lengths.tolist()

    return np.array(results)

# %%
segment_lengths_IAM = get_segment_lengths([dl_train, dl_val])
segment_lengths_Xpp = get_segment_lengths([dl_inference,])

len(segment_lengths_IAM), len(segment_lengths_Xpp)
# Out:
# (7651716, 1771)

# %%
for sl in [segment_lengths_Xpp, segment_lengths_IAM]:
    print(sl.mean(), sl.std(), sl.max(), np.quantile(sl, 0.5), np.quantile(sl, 0.98))
# Out:
# 0.03075740663339986 0.0582288076165338 0.8580945730209351 0.02013082057237625 0.10204081982374191
# 0.04772649997899526 0.08719070655718524 6.154927730560303 0.03245917335152626 0.3021262019872666

# %% [markdown]
# Remove outliers

# %%
segment_lengths_IAM_filtered = segment_lengths_IAM[ segment_lengths_IAM <= np.quantile(segment_lengths_IAM, 0.98) ]
segment_lengths_Xpp_filtered = segment_lengths_Xpp[ segment_lengths_Xpp <= np.quantile(segment_lengths_Xpp, 0.98) ]

for sl in [segment_lengths_Xpp_filtered, segment_lengths_IAM_filtered]:
    print(sl.mean(), sl.std(), sl.max(), np.quantile(sl, 0.5), np.quantile(sl, 0.98))
# Out:
# 0.02406824852955798 0.016340708112571448 0.10204081982374191 0.02013082057237625 0.06732454672455779
# 0.037394472426955434 0.032287028940773885 0.3021261394023895 0.03190260007977486 0.11745930761098834

# %%
plt.figure()
plt.violinplot([segment_lengths_IAM_filtered, segment_lengths_Xpp_filtered])
plt.xticks(ticks=[1, 2], labels=['IAM filtered', 'Xpp filtered'])
plt.show()

# %% [markdown]
# The distributions do look quite different. This observation strenghtens my hypothesis that the segment lengths are just too different for the model to cope with.
#
# This, unfortunately, can only be solved by resampling, which requires a time channel.
#
# Next steps:
# - Get some test data with `draw_and_store_sample.py` and repeat the notebook above including time channel.
# - Also check if using full `Carbune2020` transform makes the two distributions (IAM and test data captured w/ script) equal b/c of linear resampling. This does not need any training, strictly speaking.
